# %%
from util import get_data, plot_data
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np

# %%
#generate date range prices
sd = dt.datetime(2008,1,1)
ed = dt.datetime(2009,12,31)
lookback_pd = sd - dt.timedelta(days=50)
dates = pd.date_range(lookback_pd, ed)
syms = ['JPM']
prices_all = get_data(syms, dates)
prices = prices_all[syms]
prices.fillna(method ='ffill',inplace=True)
prices.fillna(method ='bfill',inplace=True)
prices_SPY = prices_all["SPY"] 

# normalized prices
syms_normed = prices/prices.iloc[0]
spy_normed = prices_SPY/prices_SPY.iloc[0]

print(prices)
# Out:
#               JPM
# 2007-11-12  38.33
# 2007-11-13  40.73
# 2007-11-14  40.83
# 2007-11-15  39.36
# 2007-11-16  38.96
# 2007-11-19  37.41
# 2007-11-20  37.64
# 2007-11-21  36.78
# 2007-11-23  37.93
# 2007-11-26  36.58
# 2007-11-27  38.29
# 2007-11-28  39.75
# 2007-11-29  39.47
# 2007-11-30  41.25
# 2007-12-03  40.88
# 2007-12-04  39.92
# 2007-12-05  40.60
# 2007-12-06  41.78
# 2007-12-07  41.67
# 2007-12-10  42.88
# 2007-12-11  41.54
# 2007-12-12  41.73
# 2007-12-13  41.38
# 2007-12-14  40.87
# 2007-12-17  40.26
# 2007-12-18  39.70
# 2007-12-19  39.77
# 2007-12-20  39.18
# 2007-12-21  39.89
# 2007-12-24  40.54
# ...           ...
# 2009-11-18  41.33
# 2009-11-19  40.54
# 2009-11-20  40.45
# 2009-11-23  41.23
# 2009-11-24  40.47
# 2009-11-25  40.17
# 2009-11-27  39.38
# 2009-11-30  40.48
# 2009-12-01  40.22
# 2009-12-02  39.95
# 2009-12-03  39.44
# 2009-12-04  39.77
# 2009-12-07  39.30
# 2009-12-08  39.26
# 2009-12-09  39.24
# 2009-12-10  39.32
# 2009-12-11  39.02
# 2009-12-14  39.80
# 2009-12-15  38.93
# 2009-12-16  39.41
# 2009-12-17  38.37
# 2009-12-18  39.01
# 2009-12-21  39.92
# 2009-12-22  39.96
# 2009-12-23  39.60
# 2009-12-24  39.91
# 2009-12-28  39.75
# 2009-12-29  39.53
# 2009-12-30  39.57
# 2009-12-31  39.70
#
# [539 rows x 1 columns]

# %% [markdown]
# ### RSI function

# %%
def calc_rsi(prices, lb_period=14,sd=dt.datetime(2008,1,1)):
    diff = prices.diff()
    up = diff.where(diff > 0, 0)
    down = diff.where(diff < 0, 0)
    avg_up = up.rolling(window=lb_period).mean()
    avg_down = down.rolling(window=lb_period).mean().abs()
    rsi = 100 * avg_up/(avg_up+avg_down)
    rsi = rsi.rename(columns={'JPM': 'RSI'})
    rsi = rsi[rsi.index >= sd]
    return rsi

rsi_vals = calc_rsi(prices, lb_period=14)
# rsi_vals = rsi_vals.rename(columns={'JPM': 'RSI'})
# rsi_vals = rsi_vals[rsi_vals.index >= sd]
display(rsi_vals)
# Out:
#                   RSI
# 2008-01-02  28.710125
# 2008-01-03  25.788752
# 2008-01-04  24.071703
# 2008-01-07  29.427083
# 2008-01-08  26.371062
# 2008-01-09  32.511737
# 2008-01-10  39.024390
# 2008-01-11  39.697950
# 2008-01-14  38.026608
# 2008-01-15  26.808100
# 2008-01-16  38.442822
# 2008-01-17  38.164251
# 2008-01-18  37.950360
# 2008-01-22  41.729323
# 2008-01-23  59.653317
# 2008-01-24  58.192420
# 2008-01-25  57.093822
# 2008-01-28  60.233298
# 2008-01-29  68.536969
# 2008-01-30  67.345845
# 2008-01-31  65.632054
# 2008-02-01  68.660022
# 2008-02-04  61.388175
# 2008-02-05  60.980592
# 2008-02-06  55.913978
# 2008-02-07  63.101302
# 2008-02-08  60.466377
# 2008-02-11  56.408809
# 2008-02-12  41.773103
# 2008-02-13  47.076462
# ...               ...
# 2009-11-18  44.736842
# 2009-11-19  55.225989
# 2009-11-20  49.062500
# 2009-11-23  53.889675
# 2009-11-24  51.766304
# 2009-11-25  36.573311
# 2009-11-27  34.259259
# 2009-11-30  36.888889
# 2009-12-01  36.403509
# 2009-12-02  33.620690
# 2009-12-03  36.055470
# 2009-12-04  41.459627
# 2009-12-07  37.370753
# 2009-12-08  36.119403
# 2009-12-09  33.947773
# 2009-12-10  39.482759
# 2009-12-11  38.103161
# 2009-12-14  38.103161
# 2009-12-15  37.418301
# 2009-12-16  43.968254
# 2009-12-17  42.290076
# 2009-12-18  37.931034
# 2009-12-21  47.774481
# 2009-12-22  50.076805
# 2009-12-23  51.257862
# 2009-12-24  51.104101
# 2009-12-28  53.731343
# 2009-12-29  52.173913
# 2009-12-30  52.648475
# 2009-12-31  53.025478
#
# [505 rows x 1 columns]

# %%
def rsi_plot(rsi_vals):
    plt.figure(figsize=(20, 6))
    plt.plot(rsi_vals.index, rsi_vals, label='RSI', color='blue')
    plt.axhline(70, color='r', linestyle='--', label='Overbought (70)')
    plt.axhline(30, color='g', linestyle='--', label='Oversold (30)')
    plt.fill_between(rsi_vals.index, 30, 70, color='lightgrey', alpha=0.3) 
    plt.fill_between(rsi_vals.index, rsi_vals['RSI'], 30, where=rsi_vals['RSI'] < 30, color='green', alpha=0.5, label='Buy Signal')
    plt.fill_between(rsi_vals.index, rsi_vals['RSI'], 70, where=rsi_vals['RSI'] > 70, color='red', alpha=0.5, label='Sell Signal')
    plt.grid()
    plt.margins(x=0.002) 
    plt.xlabel('Date')
    plt.ylabel('RSI')
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))  
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%b %Y")) 
    plt.xticks(rotation=30)
    plt.title('RSI - Relative Strength Index')
    plt.legend()
    return plt.savefig('RSI.png')

rsi_plot(rsi_vals)

# %% [markdown]
# ### EMA function

# %%
def calc_ema(prices, lb_period=20):
    ema = prices.ewm(span=lb_period, adjust=False).mean()
    return ema

ema_vals = calc_ema(prices, lb_period=20)
ema_vals = ema_vals.rename(columns={'JPM': 'EMA'})
ema_vals = ema_vals[ema_vals.index >= sd]
#prices['Momentum'] = mom_vals
display(ema_vals)
# Out:
#                   EMA
# 2008-01-02  39.854265
# 2008-01-03  39.696716
# 2008-01-04  39.471315
# 2008-01-07  39.303571
# 2008-01-08  39.008945
# 2008-01-09  38.790950
# 2008-01-10  38.687050
# 2008-01-11  38.552093
# 2008-01-14  38.473798
# 2008-01-15  38.212484
# 2008-01-16  38.172248
# 2008-01-17  38.014891
# 2008-01-18  37.833473
# 2008-01-22  37.779808
# 2008-01-23  38.153160
# 2008-01-24  38.425240
# 2008-01-25  38.557122
# 2008-01-28  38.844063
# 2008-01-29  39.266533
# 2008-01-30  39.640196
# 2008-01-31  39.983035
# 2008-02-01  40.366555
# 2008-02-04  40.537360
# 2008-02-05  40.489040
# 2008-02-06  40.431036
# 2008-02-07  40.499509
# 2008-02-08  40.449079
# 2008-02-11  40.362500
# 2008-02-12  40.281310
# 2008-02-13  40.276423
# ...               ...
# 2009-11-18  41.597908
# 2009-11-19  41.497155
# 2009-11-20  41.397426
# 2009-11-23  41.381481
# 2009-11-24  41.294673
# 2009-11-25  41.187561
# 2009-11-27  41.015413
# 2009-11-30  40.964421
# 2009-12-01  40.893524
# 2009-12-02  40.803664
# 2009-12-03  40.673792
# 2009-12-04  40.587716
# 2009-12-07  40.465077
# 2009-12-08  40.350307
# 2009-12-09  40.244564
# 2009-12-10  40.156510
# 2009-12-11  40.048271
# 2009-12-14  40.024626
# 2009-12-15  39.920376
# 2009-12-16  39.871769
# 2009-12-17  39.728743
# 2009-12-18  39.660291
# 2009-12-21  39.685026
# 2009-12-22  39.711214
# 2009-12-23  39.700622
# 2009-12-24  39.720563
# 2009-12-28  39.723366
# 2009-12-29  39.704950
# 2009-12-30  39.692098
# 2009-12-31  39.692851
#
# [505 rows x 1 columns]

# %%
# Out:
#               JPM
# 2007-11-12  38.33
# 2007-11-13  40.73
# 2007-11-14  40.83
# 2007-11-15  39.36
# 2007-11-16  38.96
# 2007-11-19  37.41
# 2007-11-20  37.64
# 2007-11-21  36.78
# 2007-11-23  37.93
# 2007-11-26  36.58
# 2007-11-27  38.29
# 2007-11-28  39.75
# 2007-11-29  39.47
# 2007-11-30  41.25
# 2007-12-03  40.88
# 2007-12-04  39.92
# 2007-12-05  40.60
# 2007-12-06  41.78
# 2007-12-07  41.67
# 2007-12-10  42.88
# 2007-12-11  41.54
# 2007-12-12  41.73
# 2007-12-13  41.38
# 2007-12-14  40.87
# 2007-12-17  40.26
# 2007-12-18  39.70
# 2007-12-19  39.77
# 2007-12-20  39.18
# 2007-12-21  39.89
# 2007-12-24  40.54
# ...           ...
# 2009-11-18  41.33
# 2009-11-19  40.54
# 2009-11-20  40.45
# 2009-11-23  41.23
# 2009-11-24  40.47
# 2009-11-25  40.17
# 2009-11-27  39.38
# 2009-11-30  40.48
# 2009-12-01  40.22
# 2009-12-02  39.95
# 2009-12-03  39.44
# 2009-12-04  39.77
# 2009-12-07  39.30
# 2009-12-08  39.26
# 2009-12-09  39.24
# 2009-12-10  39.32
# 2009-12-11  39.02
# 2009-12-14  39.80
# 2009-12-15  38.93
# 2009-12-16  39.41
# 2009-12-17  38.37
# 2009-12-18  39.01
# 2009-12-21  39.92
# 2009-12-22  39.96
# 2009-12-23  39.60
# 2009-12-24  39.91
# 2009-12-28  39.75
# 2009-12-29  39.53
# 2009-12-30  39.57
# 2009-12-31  39.70
#
# [539 rows x 1 columns]

# %%
def ema_plot(prices, ema_vals, sd=dt.datetime(2008,1,1)):
    adj_price = prices[prices.index >= sd]
    plt.figure(figsize=(20, 6))
    plt.plot(ema_vals.index, ema_vals, label='EMA', color='blue')
    plt.plot(adj_price.index, adj_price, label='Prices', color='black')
    plt.fill_between(ema_vals.index, ema_vals['EMA'], adj_price['JPM'], where=(ema_vals['EMA'] < adj_price['JPM']), color='green', alpha=0.5, label='Bullish')
    plt.fill_between(ema_vals.index, ema_vals['EMA'], adj_price['JPM'], where=(ema_vals['EMA'] >= adj_price['JPM']), color='red', alpha=0.5, label='Bearish')
    plt.grid()
    plt.margins(x=0.002) 
    plt.xlabel('Date')
    plt.ylabel('Exponential Moving Average')
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))  
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%b %Y")) 
    plt.xticks(rotation=30)
    plt.title('EMA - Exponential Moving Average (20 day)')
    plt.legend()
    return plt.savefig('EMA.png')

ema_plot(prices,ema_vals)

#     plt.fill_between(ema_vals.index, ema_vals['EMA'], 0, where=ema_vals['EMA'] < 0, color='green', alpha=0.5, label='Buy Signal')
#     plt.fill_between(ema_vals.index, ema_vals['EMA'], 0, where=ema_vals['EMA'] > prices['JPM'], color='red', alpha=0.5, label='Sell Signal')
    #plt.fill_between(ema_vals.index, ema_vals, prices, where=ema_vals['EMA'] > prices['JPM'], color='lightgrey', alpha=0.5, label='EMA > Prices')

# %% [markdown]
# ### MACD function

# %%
def calc_macd(prices, short_lb=12, long_lb=26, sig_period=9):
    short = get_ema(prices, short_lb)
    long = get_ema(prices, long_lb)
    macd = short-long
    macd_sig = calc_ema(macd,sig_period)
    return macd, macd_sig

# %%
macd_vals, sig_vals = calc_macd(prices,short_lb=12, long_lb=26, sig_period=9)
macd_vals = macd_vals.rename(columns={'JPM': 'MACD'})
macd_vals = macd_vals[macd_vals.index >= sd]

sig_vals = sig_vals.rename(columns={'JPM': 'Signal'})
sig_vals = sig_vals[sig_vals.index >= sd]


display(sig_vals)
# Out:
#               Signal
# 2008-01-02  0.182391
# 2008-01-03  0.103430
# 2008-01-04  0.008914
# 2008-01-07 -0.084354
# 2008-01-08 -0.195691
# 2008-01-09 -0.303933
# 2008-01-10 -0.388233
# 2008-01-11 -0.459083
# 2008-01-14 -0.509404
# 2008-01-15 -0.574966
# 2008-01-16 -0.612470
# 2008-01-17 -0.649286
# 2008-01-18 -0.688802
# 2008-01-22 -0.707863
# 2008-01-23 -0.640812
# 2008-01-24 -0.532851
# 2008-01-25 -0.422838
# 2008-01-28 -0.288263
# 2008-01-29 -0.117408
# 2008-01-30  0.066061
# 2008-01-31  0.248466
# 2008-02-01  0.432361
# 2008-02-04  0.577048
# 2008-02-05  0.654278
# 2008-02-06  0.681294
# 2008-02-07  0.694131
# 2008-02-08  0.676998
# 2008-02-11  0.633576
# 2008-02-12  0.574030
# 2008-02-13  0.517678
# ...              ...
# 2009-11-18 -0.241804
# 2009-11-19 -0.257369
# 2009-11-20 -0.278248
# 2009-11-23 -0.288286
# 2009-11-24 -0.302470
# 2009-11-25 -0.322607
# 2009-11-27 -0.357287
# 2009-11-30 -0.380901
# 2009-12-01 -0.399621
# 2009-12-02 -0.417690
# 2009-12-03 -0.441587
# 2009-12-04 -0.461613
# 2009-12-07 -0.484610
# 2009-12-08 -0.507797
# 2009-12-09 -0.529049
# 2009-12-10 -0.545493
# 2009-12-11 -0.561603
# 2009-12-14 -0.562936
# 2009-12-15 -0.567533
# 2009-12-16 -0.564985
# 2009-12-17 -0.573396
# 2009-12-18 -0.576717
# 2009-12-21 -0.560841
# 2009-12-22 -0.531849
# 2009-12-23 -0.500687
# 2009-12-24 -0.463711
# 2009-12-28 -0.426525
# 2009-12-29 -0.393696
# 2009-12-30 -0.363781
# 2009-12-31 -0.334360
#
# [505 rows x 1 columns]

# %%
def macd_plot(macd_vals, sig_vals):
    hist = macd_vals['MACD'] - sig_vals['Signal']
    plt.figure(figsize=(20, 6))
    plt.plot(macd_vals.index, macd_vals, label='MACD', color='blue')
    plt.plot(sig_vals.index, sig_vals, label='Signal', color='black')
    plt.bar(hist.index, hist, width=1.5, color='purple', alpha=0.5, label='MACD Histogram')
    plt.fill_between(macd_vals.index, macd_vals['MACD'], sig_vals['Signal'], where=(macd_vals['MACD'] < sig_vals['Signal']), color='red', alpha=0.5, label='Sell Signal')
    plt.fill_between(macd_vals.index, macd_vals['MACD'], sig_vals['Signal'], where=(macd_vals['MACD'] >= sig_vals['Signal']), color='green', alpha=0.5, label='Buy Signal')

    plt.grid()
    plt.margins(x=0.002) 
    plt.xlabel('Date')
    plt.ylabel('MACD')
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))  
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%b %Y")) 
    plt.xticks(rotation=30)
    plt.title('MACD - Moving Average Convergence/Divergence indicator (12,26,9)')
    plt.legend()
    return plt.savefig('MACD.png')
    
macd_plot(macd_vals, sig_vals)

# %% [markdown]
# ### Momentum function

# %%
def calc_momentum(prices, lb_period=20):
    momentum = (prices/prices.shift(lb_period - 1)) - 1
    return momentum

mom_vals = calc_momentum(prices, lb_period=20)
mom_vals = mom_vals.rename(columns={'JPM': 'Momentum'})
mom_vals = mom_vals[mom_vals.index >= sd]
#prices['Momentum'] = mom_vals
display(mom_vals)
# Out:
#             Momentum
# 2008-01-02 -0.036323
# 2008-01-03 -0.059113
# 2008-01-04 -0.106510
# 2008-01-07 -0.095032
# 2008-01-08 -0.155550
# 2008-01-09 -0.116033
# 2008-01-10 -0.096573
# 2008-01-11 -0.099323
# 2008-01-14 -0.076829
# 2008-01-15 -0.112519
# 2008-01-16 -0.048111
# 2008-01-17 -0.081720
# 2008-01-18 -0.078356
# 2008-01-22 -0.065681
# 2008-01-23  0.028614
# 2008-01-24  0.009104
# 2008-01-25  0.008870
# 2008-01-28  0.062628
# 2008-01-29  0.096529
# 2008-01-30  0.122693
# 2008-01-31  0.131937
# 2008-02-01  0.178945
# 2008-02-04  0.118006
# 2008-02-05  0.105496
# 2008-02-06  0.086057
# 2008-02-07  0.091512
# 2008-02-08  0.072444
# 2008-02-11  0.047972
# 2008-02-12  0.105793
# 2008-02-13  0.064567
# ...              ...
# 2009-11-18 -0.050976
# 2009-11-19 -0.059178
# 2009-11-20 -0.031138
# 2009-11-23 -0.014108
# 2009-11-24 -0.004673
# 2009-11-25 -0.049231
# 2009-11-27 -0.010553
# 2009-11-30 -0.002218
# 2009-12-01 -0.011308
# 2009-12-02 -0.006466
# 2009-12-03 -0.056459
# 2009-12-04 -0.039836
# 2009-12-07 -0.069822
# 2009-12-08 -0.067015
# 2009-12-09 -0.070803
# 2009-12-10 -0.046788
# 2009-12-11 -0.045265
# 2009-12-14 -0.029505
# 2009-12-15 -0.053259
# 2009-12-16 -0.046455
# 2009-12-17 -0.053527
# 2009-12-18 -0.035600
# 2009-12-21 -0.031773
# 2009-12-22 -0.012602
# 2009-12-23 -0.014190
# 2009-12-24  0.013459
# 2009-12-28 -0.018034
# 2009-12-29 -0.017156
# 2009-12-30 -0.009512
# 2009-12-31  0.006592
#
# [505 rows x 1 columns]

# %%
def mom_plot(mom_vals):
    plt.figure(figsize=(20, 6))
    plt.plot(mom_vals.index, mom_vals, label='Momentum', color='blue')
    plt.axhline(0, color='purple', linestyle='--')
    plt.fill_between(mom_vals.index, mom_vals['Momentum'], 0, where=mom_vals['Momentum'] < 0, color='green', alpha=0.5, label='Buy Signal')
    plt.fill_between(mom_vals.index, mom_vals['Momentum'], 0, where=mom_vals['Momentum'] > 0, color='red', alpha=0.5, label='Sell Signal')
    plt.grid()
    plt.margins(x=0.002) 
    plt.xlabel('Date')
    plt.ylabel('Momentum')
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))  
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%b %Y")) 
    plt.xticks(rotation=30)
    plt.title('Momentum (20 day lookback period)')
    plt.legend()
    return plt.savefig('Momentum.png')
    
mom_plot(mom_vals)

# %% [markdown]
# ### BBP function

# %%
def calc_bbp(prices, lb_period=20):
    mean = prices.rolling(window=lb_period).mean()
    std = prices.rolling(window=lb_period).std()
    lower = mean + std*2
    upper = mean - std*2
    pct_band = 100 * ((prices-lower)/(upper-lower))
    return pct_band

bbp_vals = calc_bbp(prices, lb_period=20)
bbp_vals = bbp_vals.rename(columns={'JPM': 'Bollinger Band Percentage'})
bbp_vals = bbp_vals[bbp_vals.index >= sd]
display(bbp_vals)
#prices['Bollinger Band Percentage'] = bbp_vals
# Out:
#             Bollinger Band Percentage
# 2008-01-02                  93.903800
# 2008-01-03                  93.958594
# 2008-01-04                 101.185704
# 2008-01-07                  89.291045
# 2008-01-08                 104.062221
# 2008-01-09                  92.717848
# 2008-01-10                  74.728990
# 2008-01-11                  79.276226
# 2008-01-14                  69.530942
# 2008-01-15                  98.440732
# 2008-01-16                  61.376078
# 2008-01-17                  80.463423
# 2008-01-18                  83.662099
# 2008-01-22                  62.418177
# 2008-01-23                  -5.530172
# 2008-01-24                   6.503012
# 2008-01-25                  22.943318
# 2008-01-28                   1.962948
# 2008-01-29                  -8.348307
# 2008-01-30                   0.826218
# 2008-01-31                   6.889065
# 2008-02-01                   6.376881
# 2008-02-04                  25.354446
# 2008-02-05                  44.919339
# 2008-02-06                  47.771976
# 2008-02-07                  37.888085
# 2008-02-08                  50.009545
# 2008-02-11                  55.350936
# 2008-02-12                  56.667656
# 2008-02-13                  51.865946
# ...                               ...
# 2009-11-18                  54.192520
# 2009-11-19                  74.222133
# 2009-11-20                  75.740092
# 2009-11-23                  48.215701
# 2009-11-24                  72.209216
# 2009-11-25                  80.730885
# 2009-11-27                  99.776337
# 2009-11-30                  66.640068
# 2009-12-01                  74.303196
# 2009-12-02                  80.724982
# 2009-12-03                  92.730671
# 2009-12-04                  79.750026
# 2009-12-07                  88.316008
# 2009-12-08                  86.368745
# 2009-12-09                  84.270005
# 2009-12-10                  80.825858
# 2009-12-11                  86.762061
# 2009-12-14                  59.338458
# 2009-12-15                  84.977850
# 2009-12-16                  66.930670
# 2009-12-17                  99.294691
# 2009-12-18                  73.770185
# 2009-12-21                  39.225301
# 2009-12-22                  32.424400
# 2009-12-23                  46.456843
# 2009-12-24                  30.124521
# 2009-12-28                  39.130096
# 2009-12-29                  47.509323
# 2009-12-30                  42.913748
# 2009-12-31                  33.802801
#
# [505 rows x 1 columns]

# %%
def bbp_plot(bbp_vals):
    plt.figure(figsize=(20, 6))
    plt.plot(bbp_vals.index, bbp_vals, label='BBP', color='blue')
    plt.axhline(0, color='purple', linestyle='--', label='Lower Band')
    plt.axhline(100, color='r', linestyle='--', label='Upper Band')
    plt.fill_between(bbp_vals.index, 0, 100, color='lightgrey', alpha=0.3) 
    plt.grid()
    plt.margins(x=0.002) 
    plt.xlabel('Date')
    plt.ylabel('BBP%')
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))  
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%b %Y")) 
    plt.xticks(rotation=30)
    plt.title('BBP - Bollinger Band Percentage')
    plt.legend()
    return plt.show()
    #return plt.savefig('BBP.png')

bbp_plot(bbp_vals)
